# %% [markdown]
# ## Whale list

# %%
whale_list=['https://whalewisdom.com/filer/berkshire-hathaway-inc',
            'https://whalewisdom.com/filer/scion-asset-management-llc',
            'https://whalewisdom.com/filer/duquesne-family-office-llc',
            'https://whalewisdom.com/filer/pershing-square-capital-management-l-p',
            'https://whalewisdom.com/filer/appaloosa-management-lp',
            'https://whalewisdom.com/filer/childrens-investment-fund-management-uk-llp',
            'https://whalewisdom.com/filer/ark-investment-management-llc',
            'https://whalewisdom.com/filer/tiger-global-management-llc',
           ]

# %%
from wisdom_whale import WISDOM_WHALE
for whale_url in whale_list:
    print("=" * 30)
    filename= whale_url.split('/')[-1].replace('-','_').upper()
    print(filename)
    print(whale_url)
    for select_q in range(3):
        ww = WISDOM_WHALE(whale_url, select_q, verbose=False)
        data = ww.plot_holdings()
        print(data)
        data = ww.plot_portfolio_comparasion()
        print(data)
# Out:
# ...
# BERKSHIRE_HATHAWAY_INC
# https://whalewisdom.com/filer/berkshire-hathaway-inc
#
# Current Combined 13F/13D/G
# Sector
# COMMUNICATIONS                      0.029946
# CONSUMER DISCRETIONARY              0.013115
# CONSUMER STAPLES                    0.146646
# ENERGY                              0.110553
# FINANCE                             0.387498
# HEALTH CARE                         0.023310
# INDUSTRIALS                         0.000730
# INFORMATION TECHNOLOGY              0.282358
# MATERIALS                           0.002193
# UTILITIES AND TELECOMMUNICATIONS    0.003651
# Name: weight of Portfolio, dtype: float64
# None
#
# 2024-12-31
# Sector
# COMMUNICATIONS                      0.029305
# CONSUMER DISCRETIONARY              0.013133
# CONSUMER STAPLES                    0.146846
# ENERGY                              0.113156
# FINANCE                             0.388028
# HEALTH CARE                         0.020204
# INDUSTRIALS                         0.000731
# ...

# %%
# from google.colab import files
# !zip -r /content/results.zip /content/results
# files.download('/content/results.zip')

# %% [markdown]
# ## Quick guide

# %%
from wisdom_whale import WISDOM_WHALE
url = "https://whalewisdom.com/filer/duquesne-family-office-llc"
ww = WISDOM_WHALE(url, verbose=True)

# %%
ww.plot_holdings()

# %%
ww.plot_portfolio_comparasion()
